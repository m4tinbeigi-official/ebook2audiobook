# %% [markdown]
# <a href="https://colab.research.google.com/github/m4tinbeigi-official/ebook2audiobook/blob/main/Notebooks/colab_ebook2audiobook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Welcome to the ebook2audiobook free google colab!
# ## 🌟 Features
#
# - 📖 Converts eBooks to text format with Calibre.
# - 📚 Splits eBook into chapters for organized audio.
# - 🎙️ High-quality text-to-speech with Coqui XTTS and Fairseq.
# - 🗣️ Optional voice cloning with your own voice file or choose from our pre-made fine-tuned models!
# - 🌍 Supports multiple languages! Arabic (ar), Chinese (zh-cn), Czech (cs), Dutch (nl), English (en), French (fr), German (de), Hindi (hi), Hungarian (hu), Italian (it), Japanese (ja), Korean (ko), Polish (pl), Portuguese (pt), Russian (ru), Spanish (es), Turkish (tr), Vietnamese (vi), [+ 1107 languages via Fairseq](https://dl.fbaipublicfiles.com/mms/tts/all-tts-languages.html)
# ## Want to run locally for free? ⬇
# ## [Check out the ebook2audiobook github!](https://github.com/DrewThomasson/ebook2audiobook)

# %%
# @title 🛠️ Install requirments
#!DEBIAN_FRONTEND=noninteractive
# !sudo apt-get update # && sudo apt-get -y upgrade
# !sudo apt-get -y install libegl1
# !sudo apt-get -y install libopengl0
# !sudo apt-get -y install libxcb-cursor0
# !sudo -v && wget -nv -O- https://download.calibre-ebook.com/linux-installer.sh | sudo sh /dev/stdin
# !sudo apt-get install -y ffmpeg
# !apt-get install -y mecab libmecab-dev mecab-ipadic-utf8
# !pip install mecab-python3
#!sudo apt-get install -y calibre
#!git clone https://github.com/DrewThomasson/ebook2audiobook.git
# !git clone https://github.com/DrewThomasson/ebook2audiobook.git temp_repo && mv temp_repo/* temp_repo/.* ./ && rm -rf temp_repo
# !pip install -r /content/requirements.txt
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libegl1 is already the newest version (1.4.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libopengl0 is already the newest version (1.4.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libxcb-cursor0 is already the newest version (0.1.1-4ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# 2025-02-19 01:28:27 URL:https://download.calibre-ebook.com/linux-installer.sh [35050/35050] -> "-" [1]
# Using python executable: /usr/bin/python3
# Installing to /opt/calibre
# Downloading tarball signature securely...
# Using previously downloaded calibre-7.26.0-x86_64.txz
# Extracting files to /opt/calibre ...
# Extracting application files...
# Creating symlinks...
# 	Symlinking /opt/calibre/ebook-device to /usr/bin/ebook-device
# 	Symlinking /opt/calibre/ebook-meta to /usr/bin/ebook-meta
# 	Symlinking /opt/calibre/ebook-convert to /usr/bin/ebook-convert
# 	Symlinking /opt/calibre/ebook-polish to /usr/bin/ebook-polish
# 	Symlinking /opt/calibre/markdown-calibre to /usr/bin/markdown-calibre
# 	Symlinking /opt/calibre/web2disk to /usr/bin/web2disk
# 	Symlinking /opt/calibre/calibre-server to /usr/bin/calibre-server
# 	Symlinking /opt/calibre/lrf2lrs to /usr/bin/lrf2lrs
# 	Symlinking /opt/calibre/lrs2lrf to /usr/bin/lrs2lrf
# 	Symlinking /opt/calibre/calibre-debug to /usr/bin/calibre-debug
# 	Symlinking /opt/calibre/calibredb to /usr/bin/calibredb
# 	Symlinking /opt/calibre/calibre-parallel to /usr/bin/calibre-parallel
# 	Symlinking /opt/calibre/calibre-customize to /usr/bin/calibre-customize
# 	Symlinking /opt/calibre/fetch-ebook-metadata to /usr/bin/fetch-ebook-metadata
# 	Symlinking /opt/calibre/calibre-smtp to /usr/bin/calibre-smtp
# 	Symlinking /opt/calibre/calibre to /usr/bin/calibre
# 	Symlinking /opt/calibre/lrfviewer to /usr/bin/lrfviewer
# 	Symlinking /opt/calibre/ebook-viewer to /usr/bin/ebook-viewer
# 	Symlinking /opt/calibre/ebook-edit to /usr/bin/ebook-edit
# Setting up command-line completion...
# Installing zsh completion to: /usr/share/zsh/vendor-completions/_calibre
# Failed to find directory to install bash completions, using default.
# Installing bash completion to: /usr/share/bash-completion/completions/
# Failed to import PyQt module: PyQt6.QtWebEngineCore with error: libXtst.so.6: cannot open shared object file: No such file or directory
#
# ____________________ WARNING ____________________
# Setting up completion failed with error:
# __________________________________________________
#
#
# 	Traceback (most recent call last):
# 	  File "calibre/linux.py", line 838, in setup_completion
# 	  File "calibre/linux.py", line 588, in write_completion
# 	  File "bypy-importer.py", line 279, in exec_module
# 	  File "calibre/gui2/tweak_book/main.py", line 12, in <module>
# 	  File "bypy-importer.py", line 279, in exec_module
# 	  File "calibre/ebooks/oeb/polish/check/css.py", line 12, in <module>
# 	ImportError: cannot import name 'QWebEnginePage' from 'qt.webengine' (/opt/calibre/lib/calibre-extensions/python-lib.bypy.frozen/qt/webengine.pyc)
#
# Setting up desktop integration...
# xdg-desktop-menu: No writable system menu directory found.
#
# ____________________ WARNING ____________________
# Setting up desktop integration failed with error:
# __________________________________________________
#
#
# 	Traceback (most recent call last):
# 	  File "calibre/linux.py", line 859, in setup_desktop_integration
# 	  File "calibre/linux.py", line 881, in do_setup_desktop_integration
# 	  File "calibre/linux.py", line 961, in install_xdg_junk
# 	  File "subprocess.py", line 413, in check_call
# 	subprocess.CalledProcessError: Command 'xdg-desktop-menu install --noupdate ./calibre-gui.desktop' returned non-zero exit status 3.
#
# Creating un-installer: /usr/bin/calibre-uninstall
#
#
# There were 2 warnings
#
# * Setting up completion failed with error:
#
# * Setting up desktop integration failed with error:
#
# Run "calibre" to start calibre
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libmecab-dev is already the newest version (0.996-14build9).
# mecab-ipadic-utf8 is already the newest version (2.7.0-20070801+main-3).
# mecab is already the newest version (0.996-14build9).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Requirement already satisfied: mecab-python3 in /usr/local/lib/python3.11/dist-packages (1.0.10)
# Cloning into 'temp_repo'...
# remote: Enumerating objects: 3933, done.
# remote: Counting objects: 100% (1078/1078), done.
# remote: Compressing objects: 100% (415/415), done.
# remote: Total 3933 (delta 880), reused 666 (delta 661), pack-reused 2855 (from 3)
# Receiving objects: 100% (3933/3933), 220.64 MiB | 36.71 MiB/s, done.
# Resolving deltas: 100% (2133/2133), done.
# Updating files: 100% (9433/9433), done.
# mv: cannot move 'temp_repo/assets' to './assets': Directory not empty
# mv: cannot move 'temp_repo/audiobooks' to './audiobooks': Directory not empty
# mv: cannot move 'temp_repo/dockerfiles' to './dockerfiles': Directory not empty
# mv: cannot move 'temp_repo/ebook2audiobookXTTS.egg-info' to './ebook2audiobookXTTS.egg-info': Directory not empty
# mv: cannot move 'temp_repo/ebooks' to './ebooks': Directory not empty
# mv: cannot move 'temp_repo/lib' to './lib': Directory not empty
# mv: cannot move 'temp_repo/models' to './models': Directory not empty
# mv: cannot move 'temp_repo/Notebooks' to './Notebooks': Directory not empty
# mv: cannot move 'temp_repo/readme' to './readme': Directory not empty
# mv: cannot move 'temp_repo/tmp' to './tmp': Directory not empty
# mv: cannot move 'temp_repo/tools' to './tools': Directory not empty
# mv: cannot move 'temp_repo/voices' to './voices': Directory not empty
# mv: cannot move 'temp_repo/.' to './.': Device or resource busy
# mv: cannot move 'temp_repo/..' to './..': Device or resource busy
# mv: cannot move 'temp_repo/.git' to './.git': Directory not empty
# mv: cannot move 'temp_repo/.github' to './.github': Directory not empty
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 1)) (4.13.3)
# Requirement already satisfied: cutlet in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 2)) (0.5.0)
# Requirement already satisfied: deep_translator in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 3)) (1.11.4)
# Requirement already satisfied: demucs in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 4)) (4.0.1)
# Requirement already satisfied: docker in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 5)) (7.1.0)
# Requirement already satisfied: ebooklib in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 6)) (0.18)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 7)) (0.115.8)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 9)) (4.3.3)
# Requirement already satisfied: gradio in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 10)) (5.16.1)
# Requirement already satisfied: hangul-romanize in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 11)) (0.1.0)
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 12)) (0.92)
# Requirement already satisfied: iso-639 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 13)) (0.4.5)
# Requirement already satisfied: jieba in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 14)) (0.42.1)
# Requirement already satisfied: m4b-util in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 15)) (2025.1.6)
# Requirement already satisfied: mecab in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 16)) (0.996.5)
# Requirement already satisfied: mecab-python3 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 17)) (1.0.10)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 18)) (0.25.1)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 19)) (0.53.0)
# Requirement already satisfied: ray in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 20)) (2.42.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 21)) (2024.11.6)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 22)) (0.2.0)
# Requirement already satisfied: torchvggish in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 23)) (0.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 24)) (4.46.2)
# Requirement already satisfied: translate in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 25)) (3.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 26)) (4.67.1)
# Requirement already satisfied: unidic in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 27)) (1.1.0)
# Requirement already satisfied: coqui-tts==0.25.3 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements.txt (line 28)) (0.25.3)
# Requirement already satisfied: anyascii>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.3.2)
# Requirement already satisfied: coqpit-config<0.2.0,>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.1.2)
# Requirement already satisfied: coqui-tts-trainer<0.3.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.2.2)
# Requirement already satisfied: cython>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.0.12)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.8.1)
# Requirement already satisfied: encodec>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.1.1)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2024.10.0)
# Requirement already satisfied: gruut>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.4.0)
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (7.5.0)
# Requirement already satisfied: librosa>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.10.2.post1)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.10.0)
# Requirement already satisfied: monotonic-alignment-search>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.1.1)
# Requirement already satisfied: num2words>=0.5.14 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.5.14)
# Requirement already satisfied: numpy<2.0,>=1.25.2 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.26.4)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (24.2)
# Requirement already satisfied: pysbd>=0.3.4 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.3.4)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (6.0.2)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.13.1)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.13.1)
# Requirement already satisfied: spacy<3.8,>=3 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.7.5)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.5.1+cu124)
# Requirement already satisfied: torchaudio>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.5.1+cu124)
# Requirement already satisfied: typing-extensions>=4.10 in /usr/local/lib/python3.11/dist-packages (from coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->-r /content/requirements.txt (line 1)) (2.6)
# Requirement already satisfied: jaconv in /usr/local/lib/python3.11/dist-packages (from cutlet->-r /content/requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: fugashi in /usr/local/lib/python3.11/dist-packages (from cutlet->-r /content/requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: mojimoji in /usr/local/lib/python3.11/dist-packages (from cutlet->-r /content/requirements.txt (line 2)) (0.0.13)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from deep_translator->-r /content/requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: dora-search in /usr/local/lib/python3.11/dist-packages (from demucs->-r /content/requirements.txt (line 4)) (0.1.12)
# Requirement already satisfied: julius>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from demucs->-r /content/requirements.txt (line 4)) (0.2.7)
# Requirement already satisfied: lameenc>=1.2 in /usr/local/lib/python3.11/dist-packages (from demucs->-r /content/requirements.txt (line 4)) (1.8.1)
# Requirement already satisfied: openunmix in /usr/local/lib/python3.11/dist-packages (from demucs->-r /content/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker->-r /content/requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from ebooklib->-r /content/requirements.txt (line 6)) (5.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from ebooklib->-r /content/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi->-r /content/requirements.txt (line 7)) (0.45.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from fastapi->-r /content/requirements.txt (line 7)) (2.10.6)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from ffmpeg-python->-r /content/requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim->-r /content/requirements.txt (line 9)) (7.1.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (3.7.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (0.5.0)
# Requirement already satisfied: gradio-client==1.7.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (1.7.0)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (3.1.5)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (3.10.15)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (11.1.0)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (0.9.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (2.10.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (0.15.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio->-r /content/requirements.txt (line 10)) (0.34.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.7.0->gradio->-r /content/requirements.txt (line 10)) (14.2)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library->-r /content/requirements.txt (line 12)) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library->-r /content/requirements.txt (line 12)) (3.0.2)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library->-r /content/requirements.txt (line 12)) (2.0.6)
# Requirement already satisfied: natsort~=8.2.0 in /usr/local/lib/python3.11/dist-packages (from m4b-util->-r /content/requirements.txt (line 15)) (8.2.0)
# Requirement already satisfied: rich~=12.6.0 in /usr/local/lib/python3.11/dist-packages (from m4b-util->-r /content/requirements.txt (line 15)) (12.6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray->-r /content/requirements.txt (line 20)) (8.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from ray->-r /content/requirements.txt (line 20)) (3.17.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from ray->-r /content/requirements.txt (line 20)) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray->-r /content/requirements.txt (line 20)) (1.1.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/dist-packages (from ray->-r /content/requirements.txt (line 20)) (4.25.6)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray->-r /content/requirements.txt (line 20)) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray->-r /content/requirements.txt (line 20)) (1.5.0)
# Requirement already satisfied: resampy in /usr/local/lib/python3.11/dist-packages (from torchvggish->-r /content/requirements.txt (line 23)) (0.4.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /content/requirements.txt (line 24)) (0.5.2)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.11/dist-packages (from transformers->-r /content/requirements.txt (line 24)) (0.20.3)
# Requirement already satisfied: libretranslatepy==2.1.1 in /usr/local/lib/python3.11/dist-packages (from translate->-r /content/requirements.txt (line 25)) (2.1.1)
# Requirement already satisfied: wasabi<1.0.0,>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from unidic->-r /content/requirements.txt (line 27)) (0.10.1)
# Requirement already satisfied: plac<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from unidic->-r /content/requirements.txt (line 27)) (1.4.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio->-r /content/requirements.txt (line 10)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio->-r /content/requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.11/dist-packages (from coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (5.9.5)
# Requirement already satisfied: tensorboard>=2.17.0 in /usr/local/lib/python3.11/dist-packages (from coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.18.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.11.12)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.17.0)
# Requirement already satisfied: dateparser~=1.1.1 in /usr/local/lib/python3.11/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.13.0)
# Requirement already satisfied: gruut-lang-en~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.0.1)
# Requirement already satisfied: jsonlines~=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.2.0)
# Requirement already satisfied: networkx>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.4.2)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /usr/local/lib/python3.11/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.9.11)
# Requirement already satisfied: gruut-lang-de~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.0.1)
# Requirement already satisfied: gruut-lang-es~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.0.1)
# Requirement already satisfied: gruut-lang-fr~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.0.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio->-r /content/requirements.txt (line 10)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio->-r /content/requirements.txt (line 10)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio->-r /content/requirements.txt (line 10)) (0.14.0)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (10.6.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (4.4.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.61.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.8.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from num2words>=0.5.14->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.6.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio->-r /content/requirements.txt (line 10)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio->-r /content/requirements.txt (line 10)) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r /content/requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r /content/requirements.txt (line 7)) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator->-r /content/requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from rich~=12.6.0->m4b-util->-r /content/requirements.txt (line 15)) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from rich~=12.6.0->m4b-util->-r /content/requirements.txt (line 15)) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim->-r /content/requirements.txt (line 9)) (1.17.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.17.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (8.2.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.5.0)
# Requirement already satisfied: sudachipy!=0.6.1,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.6.10)
# Requirement already satisfied: sudachidict-core>=20211220 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (20250129)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio->-r /content/requirements.txt (line 10)) (1.5.4)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (from dora-search->demucs->-r /content/requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.11/dist-packages (from dora-search->demucs->-r /content/requirements.txt (line 4)) (1.3.4)
# Requirement already satisfied: submitit in /usr/local/lib/python3.11/dist-packages (from dora-search->demucs->-r /content/requirements.txt (line 4)) (1.5.2)
# Requirement already satisfied: treetable in /usr/local/lib/python3.11/dist-packages (from dora-search->demucs->-r /content/requirements.txt (line 4)) (0.2.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray->-r /content/requirements.txt (line 20)) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray->-r /content/requirements.txt (line 20)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray->-r /content/requirements.txt (line 20)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray->-r /content/requirements.txt (line 20)) (0.22.3)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (8.1.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (0.21.2)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->indic-nlp-library->-r /content/requirements.txt (line 12)) (4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.4.6)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.18.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (2.22)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.11/dist-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (5.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.3.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (4.3.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->librosa>=0.10.1->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.5.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (2.2.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 12)) (1.4.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (3.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.1.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (0.20.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf->dora-search->demucs->-r /content/requirements.txt (line 4)) (4.9.3)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from submitit->dora-search->demucs->-r /content/requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts==0.25.3->-r /content/requirements.txt (line 28)) (1.2.1)

# %%
# @title 🚀 Run ebook2audiobook! (Make sure to set the runtime to have gpu to have faster generation speeds! :)

# Start the app with Share=True for the gradio interface
# !python /content/app.py --share
# Out:
# ***********
# Wrong launch! ebook2audiobook must run in its own virtual environment!
# NOTE: If you are running a Docker so you are probably using an old version of ebook2audiobook.
# To solve this issue go to download the new version at https://github.com/DrewThomasson/ebook2audiobook
# If the directory python_env does not exist in the ebook2audiobook root directory,
# run your command with "./ebook2audiobook.sh" for Linux and Mac or "ebook2audiobook.cmd" for Windows
# to install it all automatically.
#
# After the first run, you are free to use your command line with:
# ----------------------------------
# ebook2audiobook.[sh|cmd] [options]
# ----------------------------------
# or
# ----------------------------------
# conda activate [./|.\]python_env
# python app.py [options]
# conda deactivate
# ----------------------------------
# Available command options, ebook2audiobook.[sh|cmd] --help
#
# ***********
